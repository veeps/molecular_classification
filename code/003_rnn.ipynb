# %% [markdown]
# # Building a RNN on SMILES data

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import pickle


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer

# %run ../assets/accuracy_loss_plots.py # function to plot accuracy and loss
# %run ../assets/confusion_matrix.py # function to plot accuracy and loss
# %config InlineBackend.figure_format = 'retina'
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Read in data

# %%
df = pd.read_csv("../data/CID_properties_nr.csv")

# %%
# lowercase column names
df.columns = df.columns.str.lower()

# %%
# remove extra classes
index_names = df[(df["drug_class"] == "antineoplastic") | (df["drug_class"] == "cns") | (df["drug_class"] == "cardio")].index

df = df.loc[index_names]

# %%
df["drug_class"].value_counts()
# Out:
# antineoplastic    1174
# cns               1141
# cardio             787
# Name: drug_class, dtype: int64

# %% [markdown]
# ## Set up X and y variables

# %%
# Make my drug class variable categorical

# %%
classes_dict = {
    "antineoplastic": 0,
    "cns": 1,
    "cardio": 2}

# %%
# map drug classes to numerical
df['drug_class'] = df['drug_class'].map(classes_dict)
df.head()
# Out:
#           cid  hbondacceptorcount  hbonddonorcount  \
# 1   134694070                   9                6
# 3     4660557                   1                1
# 4      122175                   2                2
# 5     5281077                   1                1
# 12      92913                   1                1
#
#                                        isomericsmiles  molecularweight  xlogp  \
# 1   C1CN=C(N1)NC2=C(C3=NC=CN=C3C=C2)Br.[C@@H](C(C(...          442.226    NaN
# 3                  C1C2CC3CC1CC(C2)C3NC4=CC=C(C=C4)Br          306.247    5.0
# 4                                      CC(CCC(C#C)N)N          126.203   -0.4
# 5                                  CCC(/C=C/Cl)(C#C)O          144.598    1.5
# 12                        CC(CC1=CC=CC=C1)N(C)CC#C.Cl          223.744    NaN
#
#     drug_class                  desalted_smiles
# 1            2      Brc1c(NC2=NCCN2)ccc2nccnc12
# 3            1  Brc1ccc(NC2C3CC4CC(C3)CC2C4)cc1
# 4            0                   C#CC(N)CCC(C)N
# 5            1               C#CC(O)(/C=C/Cl)CC
# 12           1            C#CCN(C)C(C)Cc1ccccc1

# %%
# check that the values are still the same
df["drug_class"].value_counts()
# Out:
# 0    1174
# 1    1141
# 2     787
# Name: drug_class, dtype: int64

# %%
# set up my X and y variables
X = df["desalted_smiles"]
y = df["drug_class"]

# %%
# Split my train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify = y, random_state = 42)

# %% [markdown]
# ## Preprocess Text

# %%
# set up tokenizer
tokenizer = Tokenizer(char_level=True, lower = False )
tokenizer.fit_on_texts(df["desalted_smiles"])
sequence_of_int = tokenizer.texts_to_sequences(df["desalted_smiles"])

# %%
X_train_tk = tokenizer.texts_to_matrix(X_train, mode='count' )
X_test_tk = tokenizer.texts_to_matrix(X_test, mode='count' )

# %%
# This is how you can recover the word index that was computed
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 50 unique tokens.

# %%
# tokenizer keeps the special characters by default! 
# This is useful for me since the special characters have significance in SMILES
word_index
# Out:
# {'C': 1,
#  'c': 2,
#  '(': 3,
#  ')': 4,
#  'O': 5,
#  '@': 6,
#  '1': 7,
#  '[': 8,
#  ']': 9,
#  '=': 10,
#  'H': 11,
#  'N': 12,
#  '2': 13,
#  '3': 14,
#  'n': 15,
#  '4': 16,
#  '/': 17,
#  '5': 18,
#  '-': 19,
#  'S': 20,
#  'l': 21,
#  'F': 22,
#  '+': 23,
#  '6': 24,
#  '\\': 25,
#  '.': 26,
#  'P': 27,
#  '#': 28,
#  's': 29,
#  'o': 30,
#  '7': 31,
#  'B': 32,
#  'r': 33,
#  '8': 34,
#  't': 35,
#  'I': 36,
#  '9': 37,
#  'e': 38,
#  'A': 39,
#  'G': 40,
#  'm': 41,
#  'M': 42,
#  '%': 43,
#  '0': 44,
#  'i': 45,
#  'T': 46,
#  'u': 47,
#  'a': 48,
#  'b': 49,
#  'X': 50}

# %% [markdown]
# # Build model

# %%
model = Sequential()
model.add(Embedding(500,32))
model.add(SimpleRNN(51))
model.add(Dense(3, activation = "softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 32)          16000
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 51)                4284
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 156
# =================================================================
# Total params: 20,440
# Trainable params: 20,440
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam", loss =  "sparse_categorical_crossentropy",
              metrics=['accuracy'])

# %%
history = model.fit(X_train_tk, y_train,
                   epochs = 30,
                   batch_size = 128, 
                   validation_data = (X_test_tk, y_test))
# Out:
# Train on 2326 samples, validate on 776 samples
# Epoch 1/30
# 2326/2326 [==============================] - 1s 523us/sample - loss: 1.0477 - accuracy: 0.4566 - val_loss: 0.9897 - val_accuracy: 0.5219
# Epoch 2/30
# 2326/2326 [==============================] - 0s 160us/sample - loss: 0.9468 - accuracy: 0.5550 - val_loss: 0.9660 - val_accuracy: 0.5580
# Epoch 3/30
# 2326/2326 [==============================] - 0s 151us/sample - loss: 0.9012 - accuracy: 0.5946 - val_loss: 0.9360 - val_accuracy: 0.5722
# Epoch 4/30
# 2326/2326 [==============================] - 0s 155us/sample - loss: 0.8683 - accuracy: 0.6062 - val_loss: 0.9311 - val_accuracy: 0.5799
# Epoch 5/30
# 2326/2326 [==============================] - 0s 154us/sample - loss: 0.8484 - accuracy: 0.6182 - val_loss: 0.9158 - val_accuracy: 0.5760
# Epoch 6/30
# 2326/2326 [==============================] - 0s 152us/sample - loss: 0.8374 - accuracy: 0.6187 - val_loss: 0.9079 - val_accuracy: 0.5838
# Epoch 7/30
# 2326/2326 [==============================] - 0s 151us/sample - loss: 0.8192 - accuracy: 0.6350 - val_loss: 0.8953 - val_accuracy: 0.6134
# Epoch 8/30
# 2326/2326 [==============================] - 0s 151us/sample - loss: 0.8118 - accuracy: 0.6440 - val_loss: 0.8980 - val_accuracy: 0.5863
# Epoch 9/30
# 2326/2326 [==============================] - 0s 153us/sample - loss: 0.7947 - accuracy: 0.6543 - val_loss: 0.8973 - val_accuracy: 0.6134
# Epoch 10/30
# 2326/2326 [==============================] - 0s 149us/sample - loss: 0.7651 - accuracy: 0.6681 - val_loss: 0.8858 - val_accuracy: 0.6160
# Epoch 11/30
# 2326/2326 [==============================] - 0s 147us/sample - loss: 0.7590 - accuracy: 0.6702 - val_loss: 0.8710 - val_accuracy: 0.6211
# Epoch 12/30
# 2326/2326 [==============================] - 0s 146us/sample - loss: 0.7419 - accuracy: 0.6857 - val_loss: 0.8806 - val_accuracy: 0.6044
# Epoch 13/30
# 2326/2326 [==============================] - 0s 147us/sample - loss: 0.7413 - accuracy: 0.6844 - val_loss: 0.8986 - val_accuracy: 0.5889
# Epoch 14/30
# 2326/2326 [==============================] - 0s 153us/sample - loss: 0.7209 - accuracy: 0.7008 - val_loss: 0.8511 - val_accuracy: 0.6186
# Epoch 15/30
# 2326/2326 [==============================] - 0s 151us/sample - loss: 0.7445 - accuracy: 0.6668 - val_loss: 0.8723 - val_accuracy: 0.6160
# Epoch 16/30
# 2326/2326 [==============================] - 0s 148us/sample - loss: 0.7266 - accuracy: 0.6926 - val_loss: 0.9098 - val_accuracy: 0.6044
# Epoch 17/30
# 2326/2326 [==============================] - 0s 142us/sample - loss: 0.7489 - accuracy: 0.6780 - val_loss: 0.9213 - val_accuracy: 0.6095
# Epoch 18/30
# 2326/2326 [==============================] - 0s 157us/sample - loss: 0.7193 - accuracy: 0.6883 - val_loss: 0.8805 - val_accuracy: 0.6392
# Epoch 19/30
# 2326/2326 [==============================] - 0s 142us/sample - loss: 0.6977 - accuracy: 0.7055 - val_loss: 0.8296 - val_accuracy: 0.6469
# Epoch 20/30
# 2326/2326 [==============================] - 0s 151us/sample - loss: 0.6661 - accuracy: 0.7253 - val_loss: 0.8278 - val_accuracy: 0.6340
# Epoch 21/30
# 2326/2326 [==============================] - 0s 142us/sample - loss: 0.6548 - accuracy: 0.7317 - val_loss: 0.8582 - val_accuracy: 0.6366
# Epoch 22/30
# 2326/2326 [==============================] - 0s 144us/sample - loss: 0.6576 - accuracy: 0.7291 - val_loss: 0.8457 - val_accuracy: 0.6314
# Epoch 23/30
# 2326/2326 [==============================] - 0s 162us/sample - loss: 0.6456 - accuracy: 0.7309 - val_loss: 0.8304 - val_accuracy: 0.6379
# Epoch 24/30
# 2326/2326 [==============================] - 0s 147us/sample - loss: 0.6182 - accuracy: 0.7377 - val_loss: 0.8570 - val_accuracy: 0.6353
# Epoch 25/30
# 2326/2326 [==============================] - 0s 146us/sample - loss: 0.6299 - accuracy: 0.7446 - val_loss: 0.8516 - val_accuracy: 0.6314
# Epoch 26/30
# 2326/2326 [==============================] - 0s 144us/sample - loss: 0.6378 - accuracy: 0.7317 - val_loss: 0.8620 - val_accuracy: 0.6418
# Epoch 27/30
# 2326/2326 [==============================] - 0s 148us/sample - loss: 0.6038 - accuracy: 0.7588 - val_loss: 0.8452 - val_accuracy: 0.6443
# Epoch 28/30
# 2326/2326 [==============================] - 0s 144us/sample - loss: 0.6396 - accuracy: 0.7377 - val_loss: 0.8827 - val_accuracy: 0.6418
# Epoch 29/30
# 2326/2326 [==============================] - 0s 196us/sample - loss: 0.6172 - accuracy: 0.7403 - val_loss: 0.8263 - val_accuracy: 0.6508
# Epoch 30/30
# 2326/2326 [==============================] - 0s 181us/sample - loss: 0.5924 - accuracy: 0.7618 - val_loss: 0.8507 - val_accuracy: 0.6585

# %% [markdown]
# ### Evaluate Model

# %%
# plot accuracy and loss for model
plot_accuracy_loss(history, epochs = 30);
#plt.savefig("../plots/accuracy_loss_rnn.png")

# %% [markdown]
# ## Generate predictions

# %%
# make predictions on test set
preds = model.predict_classes(X_test_tk)

# %%
val_acc = round(history.history['val_accuracy'][-1], 2)

# %%
# Look at confusion matrix
cnf_matrix = confusion_matrix(y_test, preds,labels=[0, 1, 2])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize = (7, 7))
plot_confusion_matrix(cnf_matrix, classes=['Antineoplastic', 'CNS', 'Cardio'],
                      title=f'Confusion Matrix for RNN Model \nAccuracy Score: {val_acc}\n' )
plt.savefig("../plots/confusion_matrix_rnn.png", dpi = 150);
# Out:
# Confusion matrix, without normalization
# [[191  68  35]
#  [ 29 225  31]
#  [ 37  65  95]]
